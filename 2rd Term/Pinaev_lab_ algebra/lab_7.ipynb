# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from sympy import *

# %% [markdown]
# 1 ЗАДАНИЕ

# %%
# построить эллипс с центром (3, 1), а = 3, е = 4/5.
e2 = Ellipse( Point(3,1), hradius=3, eccentricity=(4/5))
e2.equation()

print('ПАРАМЕТРИЧЕСКОЕ:',e2.arbitrary_point())
print('ЭКСЦЕНТРИСИТЕТ:',e2.eccentricity)
print('ФОКУСЫ:',e2.foci)
print('ФОКАЛЬНОЕ РАССТОЯНИЕ:',e2.focus_distance)
print('ПЛОЩАДЬ:',e2.area)
print('a=',e2.hradius)      # Параметр а
print('b=',e2.vradius)      # Параметр b
a = 3
b = 1.8
t = np.arange(0, 2*np.pi, 0.01)
x = a * np.cos(t) + 3
y = b * np.sin(t) + 1
plt.plot(x,y, lw=2) # line width
plt.plot(3/5,1,'or')
plt.plot(27/5,1,'or')
plt.text(3/5+0.2,1,'F2')
plt.text(27/5-0.5,1,'F1')
plt.grid()
plt.axis('equal')
plt.ylabel('Y')
plt.xlabel('X')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
# Out:
# ПАРАМЕТРИЧЕСКОЕ: Point2D(3*cos(t) + 3, 9*sin(t)/5 + 1)
# ЭКСЦЕНТРИСИТЕТ: 4/5
# ФОКУСЫ: (Point2D(3/5, 1), Point2D(27/5, 1))
# ФОКАЛЬНОЕ РАССТОЯНИЕ: 12/5
# ПЛОЩАДЬ: 5.4*pi
# a= 3
# b= 1.80000000000000

# %% [markdown]
# 2 ЗАДАНИЕ

# %%
p1 = Parabola(Point(0, 0), Line(Point( -1,8 ), Point(0 , 8)))
print('ЭКСЦЕНТРИСИТЕТ:',p1.eccentricity)
print('ФОКУС:',p1.focus)
print('ФОКАЛЬНОЕ РАССТОЯНИЕ:',p1.focal_length)
print('ДИРЕКТРИСА:',p1.directrix.equation())
print('ОСЬ СИММЕТРИИ:',p1.axis_of_symmetry.equation())
print('КАНОНИЧЕСКОЕ УРАВНЕНИЕ:',p1.equation())
x = np.arange(-10,10, 0.01)
y1 = (-x**2 + 64)/16
plt.plot(x, y1, lw=2,color='r')

plt.grid()
plt.show()
# Out:
# ЭКСЦЕНТРИСИТЕТ: 1
# ФОКУС: Point2D(0, 0)
# ФОКАЛЬНОЕ РАССТОЯНИЕ: 4
# ДИРЕКТРИСА: y - 8
# ОСЬ СИММЕТРИИ: x
# КАНОНИЧЕСКОЕ УРАВНЕНИЕ: -x**2 - 16*y + 64

# %% [markdown]
# 3 ЗАДАНИЕ

# %%
#y=(1+((x-2)**(2))/8*2)**(1/2)
a=np.sqrt(2)
b=np.sqrt(8)

t = np.arange(-3 ,3, 0.001)
x = b*np.sinh(t)
x1 = -b*np.sinh(t)
y =a*np.cosh(t)
y1 =-a*np.cosh(t)

c=(a**2+b**2)**(1/2)
plt.plot(0,-c,'or')
plt.plot(0,c,'or')
plt.text(0,-c-1.75,'F1')
plt.text(0,c+1.5,'F2')

plt.plot(x, y, lw=2)
plt.plot(x1, y, lw=2)
plt.plot(x1, y1, lw=2)
x = np.linspace(-25,25,100)
ASS1=(a/b)*x
ASS2=-(a/b)*x

plt.plot(x,ASS1)
plt.plot(x,ASS2)
plt.ylabel('$y$')
plt.xlabel('$x$')
plt.grid()
plt.show()

# %% [markdown]
# 4 задание

# %%
a=np.sqrt(2)
b=np.sqrt(8)

plt.subplot(2,2,1)
t = np.arange(-1,1, 0.001)
x = b*np.sinh(t)
x1 = -b*np.sinh(t) 
y =a*np.cosh(t)
y1 =-a*np.cosh(t)

c=(a**2+b**2)**(1/2)
plt.plot(0,-c,'or')
plt.plot(0,c,'or')
plt.text(0,-c-1.75,'F1')
plt.text(0,c+1.5,'F2')


plt.plot(x, y1, lw=2)
plt.plot(x1, y, lw=2)

x = np.linspace(-25,25,100)
ASS1=(a/b)*x
ASS2=-(a/b)*x

plt.plot(x,ASS1)
plt.plot(x,ASS2)
plt.ylabel('$y$')
plt.xlabel('$x$')
plt.axis('equal')
plt.grid()

###########################################
plt.subplot(2,2,2)
t = np.arange(-2,2, 0.001)
x = b*np.sinh(t)
x1 = -b*np.sinh(t) 
y =a*np.cosh(t)
y1 =-a*np.cosh(t)

c=(a**2+b**2)**(1/2)
plt.plot(0,-c,'or')
plt.plot(0,c,'or')
plt.text(0,-c-1.75,'F1')
plt.text(0,c+1.5,'F2')


plt.plot(x, y1, lw=2)
plt.plot(x1, y, lw=2)

x = np.linspace(-25,25,100)
ASS1=(a/b)*x
ASS2=-(a/b)*x

plt.plot(x,ASS1)
plt.plot(x,ASS2)
plt.ylabel('$y$')
plt.xlabel('$x$')
plt.axis('equal')
plt.grid()

#############################################
plt.subplot(2,2,3)
t = np.arange(-3,3, 0.001)
x = b*np.sinh(t)
x1 = -b*np.sinh(t) 
y =a*np.cosh(t)
y1 =-a*np.cosh(t)

c=(a**2+b**2)**(1/2)
plt.plot(0,-c,'or')
plt.plot(0,c,'or')
plt.text(0,-c-1.75,'F1')
plt.text(0,c+1.5,'F2')

plt.plot(x, y1, lw=2)
plt.plot(x1, y, lw=2)


x = np.linspace(-25,25,10000)
ASS1=(a/b)*x
ASS2=-(a/b)*x

plt.plot(x,ASS1)
plt.plot(x,ASS2)
plt.ylabel('$y$')
plt.xlabel('$x$')
plt.axis('equal')
plt.grid()
plt.figure(figsize=(1,1))

# %% [markdown]
# 5 задание

# %%
a=2
b=5
e1=Ellipse(Point(0,0),a,b)
print('Уравнение эллипса:',e1.equation())
p1=Parabola(Point(0,0),Line(Point(0,-2),Point(1,-2)))
print('Уравнение параболы:',p1.equation())
print(p1.intersection(e1))#точки пересечения
x=np.arange(-5,5,0.001)
y1=(x**2-4)/4
plt.plot(x, y1, lw=2,color='r')
t = np.arange(0, 2*np.pi, 0.01)
x = a * np.cos(t)
y = b * np.sin(t) 
plt.plot(x,y, lw=2)
plt.plot(-2,0,'or')
plt.plot(2,0,'or')
plt.text(-2-0.7,0-0.5,'A1')
plt.text(2+0.5,0-0.5,'A2')
plt.grid()
plt.axis('equal')
plt.ylabel('Y')
plt.xlabel('X')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
# Out:
# Уравнение эллипса: x**2/4 + y**2/25 - 1
# Уравнение параболы: -x**2 + 4*y + 4
# [Point2D(-2, 0), Point2D(2, 0)]

# %% [markdown]
# 6 задание

# %%
#тип пов-ти: эллипс
#канонич.уравнение: (x-1)^2/9 + (y-2)^2/4=1
e2 = Ellipse(Point(1, 2), 3, 2)
print('ПАРАМЕТРИЧЕСКОЕ:',e2.arbitrary_point())
print('ЭКСЦЕНТРИСИТЕТ:',e2.eccentricity)
print('ФОКУСЫ:',e2.foci)
print('ФОКАЛЬНОЕ РАССТОЯНИЕ:',e2.focus_distance)
print('ПЛОЩАДЬ:',e2.area)
print('a=',e2.hradius)      # Параметр а
print('b=',e2.vradius)      # Параметр b
e2=e2.equation()
e2=e2*36
print('Проверка:',e2.expand())
# Out:
# ПАРАМЕТРИЧЕСКОЕ: Point2D(3*cos(t) + 1, 2*sin(t) + 2)
# ЭКСЦЕНТРИСИТЕТ: sqrt(5)/3
# ФОКУСЫ: (Point2D(1 - sqrt(5), 2), Point2D(1 + sqrt(5), 2))
# ФОКАЛЬНОЕ РАССТОЯНИЕ: sqrt(5)
# ПЛОЩАДЬ: 6*pi
# a= 3
# b= 2
# Проверка: 4*x**2 - 8*x + 9*y**2 - 36*y + 4

# %% [markdown]
# ДОП++

# %%
from sympy import *
x=symbols('x')
y=symbols('y')
def Formula(A,B,D,E,F):
    a1=D**2/(4*A)
    a2=E**2/(4*B)
    if abs(A)**0.5!=int(abs(A)**0.5):
        d=A*(x**2+2*(D*x)/A*2+D**2/(4*A))
    else:
        d=(A*x**2+2*(D*x)/2+D**2/(4*A))


    if abs(B)**0.5!=int(abs(B)**0.5):
        d1=B*(y**2+2*(E*y)/B*2+E**2/(4*B))
    else:
        d1=(B*y**2+2*(E*y)/2+E**2/(4*B))

    d2=(F-a1-a2)
    print(sp.factor(d)+sp.factor(d1),'=',-d2)
A,B,D,E,F=4,9,-8,-36,4
Formula(A,B,D,E,F)
# Out:
# 4.0*(1.0*x - 1.0)**2 + 36.0*(0.5*y - 1.0)**2 = 36.0
